# %% [markdown]
# 1.1 PROJECT OVERVIEW
#
# This analysis explores movie data in order to understand factors that contribute to a movie's success both in revenue and ratings

# %% [markdown]
# 1.2 PROBLEM STATEMENT
#
# This study seeks to analyse and understand factors that comytibute to a movies success.

# %% [markdown]
#  1.3 OBJECTIVES
#
# 1. Highlight genres with the highest ratings
# 2. Show genres that generate the highest revenue
# 3. To show the relationship between budget and revenue

# %%
import numpy as np
import pandas as pd 
from numbers import Number
import sqlite3
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# 2. DATA UNDERSTANDING

# %%
import sqlite3
conn = sqlite3.connect(r"C:\Users\Peter Mutethia\Desktop\Movie-Insights\data\im.db")
#connects to the database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

print(cursor.fetchall())
#returns names of all the tables
# Out:
# [('movie_basics',), ('directors',), ('known_for',), ('movie_akas',), ('movie_ratings',), ('persons',), ('principals',), ('writers',)]

# %%
movie_basics = pd.read_sql("""
                SELECT *
                FROM movie_basics;
                """, conn)
#reads the movie_basics table from the database
movie_basics.head()
# shows the first five rows of every column from the movie_basics table
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
movie_ratings = pd.read_sql("""
                SELECT *
                FROM movie_ratings;
                """, conn)
#reads the movie_ratings table from the database
movie_ratings.head()
# shows the first five rows of every column from the movie_ratings table
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
movies = pd.merge(movie_basics, movie_ratings, on= "movie_id")
# merges the movie_basics and movie_ratings tables on movie_id which is common in both

# %%
movies.head()
#shows the first five rows of every column
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018              NaN          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %% [markdown]
# 2.1DATA CLEANING

# %%
duplicates = movies.columns[movies.columns.duplicated()]
duplicates
# checks for duplicate columns
# Out:
# Index([], dtype='object')

# %%
movies.isnull().sum()
#shows number of missing values in every column
# Out:
# movie_id              0
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes    7620
# genres              804
# averagerating         0
# numvotes              0
# dtype: int64

# %%
movies['genres'] = movies['genres'].fillna('unknown')
#fills the missing values in the genres column with unknown.
movies = movies.drop(columns=["runtime_minutes"])
#drops the runtime_minutes column

# %%
movies.isnull().sum()
#shows number of missing values in every column
# Out:
# movie_id          0
# primary_title     0
# original_title    0
# start_year        0
# genres            0
# averagerating     0
# numvotes          0
# dtype: int64

# %%
movies.head()
#shows the first five rows of every column
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year                genres  averagerating  numvotes
# 0        2013    Action,Crime,Drama            7.0        77
# 1        2019       Biography,Drama            7.2        43
# 2        2018                 Drama            6.9      4517
# 3        2018          Comedy,Drama            6.1        13
# 4        2017  Comedy,Drama,Fantasy            6.5       119

# %%
bom = pd.read_csv(r"C:\Users\Peter Mutethia\Desktop\Movie-Insights\data\bom.movie_gross.csv")
#reads the bom.movie_gross csv file

# %%
bom.head()
#shows the first five rows of every column
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
bom.isnull().sum()
#shows number of missing values in every column
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
bom["domestic_gross"] = pd.to_numeric(bom["domestic_gross"],errors="coerce")
bom["foreign_gross"] = pd.to_numeric(bom["foreign_gross"],errors="coerce")
# changes all entries in domestic_gross and foreign_gross columns to numeric

# %%
bom.isnull().sum()
#shows number of missing values in every column
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1355
# year                 0
# dtype: int64

# %%
bom = bom.dropna(subset=["domestic_gross","foreign_gross"])
# drops all missing rows in domestic_gross and foreign_gross columns
bom["studio"] = bom["studio"].fillna("unknown")
# fills all missing rows in studio column with unknown

# %%
bom.isnull().sum()
#shows number of missing values in every column
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
bom.shape
# shows total number of rows and columns respectively
# Out:
# (2004, 5)

# %% [markdown]
# I opted against using this dataset and proceeded with the movie budgets data set

# %%
tn = pd.read_csv(r"C:\Users\Peter Mutethia\Desktop\Movie-Insights\data\tn.movie_budgets.csv")
# reads the tn.movie_budgets.csv

# %%
tn.head() 
#shows the first five rows of every column
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
tn['release_year'] = pd.to_datetime(tn['release_date'], errors='coerce').dt.year
# changes all entries in release_year column to date time format

# %%
tn.isnull().sum()
#shows number of missing values in every column
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# release_year         0
# dtype: int64

# %%
tn.shape
# shows total number of rows and columns respectively
# Out:
# (5782, 7)

# %%
tmdb = pd.read_csv(r"C:\Users\Peter Mutethia\Desktop\Movie-Insights\data\tmdb.movies.csv")
#reads tmdb.movies.csv

# %%
tmdb.head()
#shows the first five rows of every column
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tmdb.shape
# shows total number of rows and columns respectively
# Out:
# (26517, 10)

# %%
tmdb.isnull().sum()
#shows number of missing values in every column
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# original_title       0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %% [markdown]
# 2.2MERGING THE DATASETS BASED ON WHAT THEY HAVE IN COMMON

# %%
movies['primary_title'] = movies['primary_title'].str.strip().str.lower()
tn['movie'] = tn['movie'].str.strip().str.lower()
tmdb['title'] = tmdb['title'].str.strip().str.lower()
# converts primary_title, movie, title to lowercase.

# %%
merged = pd.merge(movies, tn, left_on='primary_title', right_on='movie', how='inner')
#merges movies data set with the tn budgets dataset
merged_movies = pd.merge(merged, tmdb, left_on='primary_title', right_on='title', how='inner')
#merges the merged data set with the tmdb data set

# %%
merged_movies.head()
#shows the first five rows of every column
# Out:
#     movie_id  primary_title original_title_x  start_year  \
# 0  tt0249516     foodfight!       Foodfight!        2012
# 1  tt0326592  the overnight    The Overnight        2010
# 2  tt3844362  the overnight    The Overnight        2015
# 3  tt0337692    on the road      On the Road        2012
# 4  tt4339118    on the road      On the Road        2014
#
#                     genres  averagerating  numvotes  id_x release_date_x  \
# 0  Action,Animation,Comedy            1.9      8248    26   Dec 31, 2012
# 1                  unknown            7.5        24    21   Jun 19, 2015
# 2           Comedy,Mystery            6.1     14828    21   Jun 19, 2015
# 3  Adventure,Drama,Romance            6.1     37886    17   Mar 22, 2013
# 4                    Drama            6.0         6    17   Mar 22, 2013
#
#            movie  ... Unnamed: 0            genre_ids    id_y  \
# 0     foodfight!  ...       8456  [16, 28, 35, 10751]  116977
# 1  the overnight  ...      14596           [9648, 35]  308024
# 2  the overnight  ...      14596           [9648, 35]  308024
# 3    on the road  ...       5350             [12, 18]   83770
# 4    on the road  ...       5350             [12, 18]   83770
#
#    original_language  original_title_y popularity  release_date_y  \
# 0                 en        Foodfight!      4.705      2013-05-07
# 1                 en     The Overnight      6.576      2015-06-19
# 2                 en     The Overnight      6.576      2015-06-19
# 3                 en       On the Road      8.919      2012-12-21
# 4                 en       On the Road      8.919      2012-12-21
#
#            title vote_average  vote_count
# 0     foodfight!          2.1          46
# 1  the overnight          6.0         200
# 2  the overnight          6.0         200
# 3    on the road          5.6         518
# 4    on the road          5.6         518
#
# [5 rows x 24 columns]

# %%
merged_movies.shape
# shows total number of rows and columns respectively
# Out:
# (3457, 24)

# %%
merged_movies.isnull().sum()
#shows number of missing values in every column
# Out:
# movie_id             0
# primary_title        0
# original_title_x     0
# start_year           0
# genres               0
# averagerating        0
# numvotes             0
# id_x                 0
# release_date_x       0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# release_year         0
# Unnamed: 0           0
# genre_ids            0
# id_y                 0
# original_language    0
# original_title_y     0
# popularity           0
# release_date_y       0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
merged_movies = merged_movies[['movie', 'averagerating', 'production_budget', 'worldwide_gross','genres','vote_count']]
# selecting only the relevant columns

# %%
merged_movies.head()
#shows the first five rows of every column
# Out:
#            movie  averagerating production_budget worldwide_gross  \
# 0     foodfight!            1.9       $45,000,000         $73,706
# 1  the overnight            7.5          $200,000      $1,165,996
# 2  the overnight            6.1          $200,000      $1,165,996
# 3    on the road            6.1       $25,000,000      $9,313,302
# 4    on the road            6.0       $25,000,000      $9,313,302
#
#                     genres  vote_count
# 0  Action,Animation,Comedy          46
# 1                  unknown         200
# 2           Comedy,Mystery         200
# 3  Adventure,Drama,Romance         518
# 4                    Drama         518

# %%
merged_movies.shape
# shows total number of rows and columns respectively
# Out:
# (3457, 6)

# %%
merged_movies['production_budget'] = (merged_movies['production_budget'].astype(str).str.replace('[^0-9.]', '', regex=True))               
merged_movies['worldwide_gross'] = (merged_movies['worldwide_gross'].astype(str).str.replace('[^0-9.]', '', regex=True))
#converts all entries in the production_budget and worlwide gross to numeric having only didgits and decimal points

# %%
merged_movies["production_budget"] = pd.to_numeric(merged_movies["production_budget"],errors="coerce")
merged_movies["worldwide_gross"] = pd.to_numeric(merged_movies["worldwide_gross"],errors="coerce")
merged_movies["vote_count"] = pd.to_numeric(merged_movies["vote_count"],errors="coerce")
#forces all entries in the production_budget and worlwide gross to numeric

# %%
merged_movies.head()
#shows the first five rows of every column
# Out:
#            movie  averagerating  production_budget  worldwide_gross  \
# 0     foodfight!            1.9           45000000            73706
# 1  the overnight            7.5             200000          1165996
# 2  the overnight            6.1             200000          1165996
# 3    on the road            6.1           25000000          9313302
# 4    on the road            6.0           25000000          9313302
#
#                     genres  vote_count
# 0  Action,Animation,Comedy          46
# 1                  unknown         200
# 2           Comedy,Mystery         200
# 3  Adventure,Drama,Romance         518
# 4                    Drama         518

# %%
merged_movies.info()
#gives information on the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3457 entries, 0 to 3456
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie              3457 non-null   object
#  1   averagerating      3457 non-null   float64
#  2   production_budget  3457 non-null   int64
#  3   worldwide_gross    3457 non-null   int64
#  4   genres             3457 non-null   object
#  5   vote_count         3457 non-null   int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 189.1+ KB

# %%
merged_movies.describe()
#shows summary statistics
# Out:
#        averagerating  production_budget  worldwide_gross   vote_count
# count    3457.000000       3.457000e+03     3.457000e+03   3457.00000
# mean        6.292826       3.532523e+07     1.094507e+08   1369.28869
# std         1.181180       4.904120e+07     2.072428e+08   2464.48634
# min         1.600000       9.000000e+03     0.000000e+00      1.00000
# 25%         5.700000       5.000000e+06     2.455027e+06     11.00000
# 50%         6.400000       1.500000e+07     3.658851e+07    306.00000
# 75%         7.100000       4.000000e+07     1.017595e+08   1676.00000
# max         9.300000       4.250000e+08     2.776345e+09  22186.00000

# %% [markdown]
# 3.DATA ANALYSIS

# %% [markdown]
# CORRELATION MATRIX
#
# Shows how the variables are correlated by computing a correlation coefficient.

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(merged_movies[['production_budget','worldwide_gross','averagerating','genres','vote_count']].corr(), annot=True)
plt.show()
#computes the correlation matrix

# %% [markdown]
# Production budget is highly positively correlated with world wide gross with a correlation coefficient of  0.79. This shows that movies with a high production budget tend to generate more revenue.
#
# world wide gross and average rating have a low correlation coefficient of 0.16 showing a very weak positive relationship they are not strongly related
#
# production budget and average rating have a low correlation coefficient of 0.13 showing a very weak positive relationship they are not strongly related

# %% [markdown]
# HOW DIFFERENT GENRES COMPARE BASED ON MOVIE RATINGS

# %%
merged_movies['genres'] = merged_movies['genres'].str.split(',')
#splits each string into a list using the comma , as the separator for movies with more than one genre.
merged_movies_exploded = merged_movies.explode('genres')
#creates a new row for each entry in the list
merged_movies_exploded['genres'] = merged_movies_exploded['genres'].str.strip()
#removes spaces

# %%
genre_gross = merged_movies_exploded.groupby('genres')['worldwide_gross'].mean().reset_index()
#average worldwide gross for each genre.

# %%
genre_gross = genre_gross.sort_values('worldwide_gross', ascending=False)
#sorts in ascending order

# %%
top10 = genre_gross.nlargest(10, 'worldwide_gross')
#takes the top 10 highest grossing genres

# %%
plt.figure(figsize=(14, 7)) 

sns.barplot(data=genre_gross, x='genres', y='worldwide_gross')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
#plots a bar graph

# %% [markdown]
# Movies with genres; Musical animation adventure fantasy and sci-fi are the highest grossing worlwide

# %% [markdown]
# GENRES WITH THE HIGHEST RATINGS

# %%
genre_ratings = merged_movies_exploded.groupby('genres')['averagerating'].mean().reset_index()
#takes average rating of each genre

# %%
top15 = genre_ratings.sort_values('averagerating', ascending=False).head(15)
#top 15 genres by ratings

# %%
plt.figure(figsize=(14, 7))  
sns.barplot(data=top15, x='genres', y='averagerating')

plt.title('Average Movie Ratings by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# plots a bar graph

# %% [markdown]
# Movies with genres; documentary, biography, history, news and musical have the best ratings.

# %% [markdown]
# 4.CONCLUSIONS
#
# 1. Movies with a higher budget tend to gross higher world wide perhaps due to better quality and marketing but that doesn't guarantee a good return on investments.
# 2. Movies with genres; Musical animation adventure fantasy and sci-fi are the highest grossing worldwide
# 3. Movies with genres; documentary, biography, history, news and musical have the best ratings.
# 4. A movie may have high ratings but generate little revenue

# %% [markdown]
# 5.RECCOMMENDATIONS
#
# 1. It would be best to make a movie with multiple genres. A Movie with genres mystery , animation and adventure would get the company the best of both worlds
# 2. Genres; animation and adventure both rank high in world wide gross, ratings and return on investments. Mystery ranks high in return on investments This would give the company a good blend of the best of both worlds.
# 3.  The main target audience for animation adventure and mystery would be children who are often accompanied by their parents and gurdians to theatres. This would sell more tickets.
# 4. Production budget could be capped at a certain point because a bloated production budget doesn’t guarantee a good return on investments.
