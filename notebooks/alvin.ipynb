# %%
import itertools
import numpy as np
import pandas as pd 
from numbers import Number
import sqlite3
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

import pickle

# %%
file_path = r"C:\Users\Peter Mutethia\Desktop\Movie Insights\movies.csv"
df = pd.read_csv(file_path)
print(df.head())
